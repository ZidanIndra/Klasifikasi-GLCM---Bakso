# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
import pandas as pd

# Folder where the CSV files are located
folder_path = 'D:\Zidan\Citra Digital\output'

# List to hold the DataFrames
dataframes = []

# Get a list of all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# Ensure we only process up to 8 files
for i, filename in enumerate(csv_files[:8]):
    file_path = os.path.join(folder_path, filename)
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Optionally: Create separate variables for each DataFrame if needed
df1, df2, df3, df4, df5, df6, df7, df8 = dataframes[:8]

# %%
# Display first DataFrame to confirm
print(df8.head())
# Out:
#                filename    mean_R    mean_G    mean_B  contrast_R  \
# 0  Sabtu-16.20 (10).png  1.743282  1.259512  0.625562    0.001749
# 1   Sabtu-16.20 (2).png  1.739204  1.257690  0.627239    0.001682
# 2   Sabtu-16.20 (3).png  1.735909  1.254758  0.619337    0.001743
# 3   Sabtu-16.20 (4).png  1.730489  1.251839  0.626461    0.001724
# 4   Sabtu-16.20 (5).png  1.743510  1.259505  0.624078    0.001695
#
#    dissimilarity_R  homogeneity_R  energy_R  correlation_R     asm_R  ...  \
# 0         0.001745       0.999128  0.976080       0.997929  0.952731  ...
# 1         0.001679       0.999161  0.976122       0.998003  0.952813  ...
# 2         0.001740       0.999130  0.976088       0.997913  0.952747  ...
# 3         0.001721       0.999140  0.976180       0.997935  0.952928  ...
# 4         0.001693       0.999154  0.976036       0.997988  0.952646  ...
#
#    correlation_G     asm_G  entropy_G  contrast_B  dissimilarity_B  \
# ...

# %%
df1.describe()
# Out:
#           mean_R     mean_G     mean_B  contrast_R  dissimilarity_R  \
# count  10.000000  10.000000  10.000000   10.000000        10.000000
# mean    2.711931   2.367902   1.366179    0.002107         0.002066
# std     0.001945   0.003938   0.001863    0.000049         0.000048
# min     2.707850   2.362698   1.363229    0.002042         0.002001
# 25%     2.710924   2.365864   1.365159    0.002077         0.002038
# 50%     2.711885   2.366322   1.365626    0.002100         0.002061
# 75%     2.713207   2.368254   1.367368    0.002147         0.002106
# max     2.714263   2.374784   1.368934    0.002183         0.002139
#
#        homogeneity_R   energy_R  correlation_R      asm_R  entropy_R  ...  \
# count      10.000000  10.000000      10.000000  10.000000  10.000000  ...
# mean        0.998971   0.978731       0.999144   0.957915   0.868379  ...
# std         0.000024   0.000029       0.000020   0.000057   0.001115  ...
# ...

# %%
def process_dataframe(df):
    """Drop non-numeric columns and compute the mean of the remaining columns."""
    df_numeric = df.drop(columns=['filename'])  # Dropping the 'filename' column
    return df_numeric.mean()  # Returning the mean of each column

# Process all the sample dataframes
mean_sesi1 = process_dataframe(df1)
mean_sesi2 = process_dataframe(df2)
mean_sesi3 = process_dataframe(df3)
mean_sesi4 = process_dataframe(df4)
mean_sesi5 = process_dataframe(df5)
mean_sesi6 = process_dataframe(df6)
mean_sesi7 = process_dataframe(df7)
mean_sesi8 = process_dataframe(df8)

# Combine all the means into a single dataframe
mean_df = pd.DataFrame({
    'sesi1': mean_sesi1,
    'sesi2': mean_sesi2,
    'sesi3': mean_sesi3,
    'sesi4': mean_sesi4,
    'sesi5': mean_sesi5,
    'sesi6': mean_sesi6,
    'sesi7': mean_sesi7,
    'sesi8': mean_sesi8,
})

mean_df
# Out:
#                     sesi1     sesi2     sesi3     sesi4     sesi5     sesi6  \
# mean_R           2.711931  2.614937  2.268946  2.395286  1.934030  1.833528
# mean_G           2.367902  2.213293  1.849556  2.053960  1.547937  1.473780
# mean_B           1.366179  1.220288  0.916664  1.450615  0.970300  0.987232
# contrast_R       0.002107  0.001713  0.001446  0.001331  0.001370  0.001308
# dissimilarity_R  0.002066  0.001707  0.001445  0.001330  0.001370  0.001308
# homogeneity_R    0.998971  0.999147  0.999278  0.999335  0.999315  0.999346
# energy_R         0.978731  0.976601  0.976634  0.976696  0.976629  0.977008
# correlation_R    0.999144  0.999167  0.999056  0.999209  0.998735  0.998665
# asm_R            0.957915  0.953750  0.953814  0.953935  0.953805  0.954545
# entropy_R        0.868379  0.918561  0.909853  0.887930  0.893135  0.868847
# contrast_G       0.002086  0.001693  0.001451  0.001229  0.001348  0.001333
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the top-level categories (grouped labels) and their respective subcategories
concentrations = ['Baru', '4 jam', '8 jam', '12 jam', '16 jam','20 jam','24 jam','28 jam']
channels = ['Blue', 'Green', 'Red']

# The number of channels per concentration level
n_channels = len(channels)

# Flatten the x-axis labels to create a list of repeated color channels under each concentration
x_labels = [f"{channel}" for _ in concentrations for channel in channels]

# Create tick positions for both levels
tick_positions = np.arange(len(x_labels))

# Extract the feature data for each color channel and percentage
contrast_blue = mean_df.loc['contrast_B']
contrast_green = mean_df.loc['contrast_G']
contrast_red = mean_df.loc['contrast_R']

homogeneity_blue = mean_df.loc['homogeneity_B']
homogeneity_green = mean_df.loc['homogeneity_G']
homogeneity_red = mean_df.loc['homogeneity_R']

# Combine the channels for Contrast and Homogeneity
contrast = [contrast_blue[0], contrast_green[0], contrast_red[0],
            contrast_blue[1], contrast_green[1], contrast_red[1],
            contrast_blue[2], contrast_green[2], contrast_red[2],
            contrast_blue[3], contrast_green[3], contrast_red[3],
            contrast_blue[4], contrast_green[4], contrast_red[4],
            contrast_blue[5], contrast_green[5], contrast_red[5],
            contrast_blue[6], contrast_green[6], contrast_red[6],
            contrast_blue[7], contrast_green[7], contrast_red[7]]

homogeneity = [homogeneity_blue[0], homogeneity_green[0], homogeneity_red[0],
               homogeneity_blue[1], homogeneity_green[1], homogeneity_red[1],
               homogeneity_blue[2], homogeneity_green[2], homogeneity_red[2],
               homogeneity_blue[3], homogeneity_green[3], homogeneity_red[3],
               homogeneity_blue[4], homogeneity_green[4], homogeneity_red[4],
               homogeneity_blue[5], homogeneity_green[5], homogeneity_red[5],
               homogeneity_blue[6], homogeneity_green[6], homogeneity_red[6],
               homogeneity_blue[7], homogeneity_green[7], homogeneity_red[7]]

# Plotting Contrast
plt.figure(figsize=(25, 10))

plt.subplot(2, 1, 1)
plt.plot(tick_positions, contrast, label='Contrast', marker='o', color='blue')
plt.title('Contrast Across Blue, Green, Red Channels')
plt.ylabel('Average Values')
plt.grid(True)

# Set the bottom-level ticks for channels
plt.xticks(tick_positions, x_labels, rotation=0)

# Add the top-level concentration labels
for i, concentration in enumerate(concentrations):
    plt.text(i * n_channels + 1, plt.ylim()[0] - 0.0001, concentration, ha='center', va='top', fontsize=10, fontweight='bold')

# Add vertical separator lines between concentration levels
for i in range(1, len(concentrations)):
    plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)

# Plotting Homogeneity (Second Subplot)
plt.subplot(2, 1, 2)
plt.plot(tick_positions, homogeneity, label='Homogeneity', marker='o', color='orange')
plt.title('Homogeneity Across Blue, Green, Red Channels')
plt.ylabel('Average Values')
plt.grid(True)

# Set the bottom-level ticks for channels
plt.xticks(tick_positions, x_labels, rotation=0)

# Add the top-level concentration labels for the second subplot
for i, concentration in enumerate(concentrations):
    plt.text(i * n_channels + 1, plt.ylim()[0] - 0.00005, concentration, ha='center', va='top', fontsize=10, fontweight='bold')

# Add vertical separator lines between concentration levels
for i in range(1, len(concentrations)):
    plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)

plt.tight_layout()
plt.show()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp5cd\AppData\Local\Temp\ipykernel_21204\1066081676.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast = [contrast_blue[0], contrast_green[0], contrast_red[0],
# C:\Users\hp5cd\AppData\Local\Temp\ipykernel_21204\1066081676.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[1], contrast_green[1], contrast_red[1],
# ...
